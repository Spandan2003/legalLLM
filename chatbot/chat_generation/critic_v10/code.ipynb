# %%
import pandas as pd

# %%
data = pd.read_csv('./chatbot/chat_generation/critic_v10/result_df_v1 copy.csv', index_col=0)
data
# Out:
#                                                   Chat  \
# 0    AI: Hi! I am your consumer grievance assistanc...
# 1    AI: Hi! I am your consumer grievance assistanc...
# 2    AI: Hi! I am your consumer grievance assistanc...
# 3    AI: Hi! I am your consumer grievance assistanc...
# 4    AI: Hi! I am your consumer grievance assistanc...
# ..                                                 ...
# 97   AI: Hi! I am your consumer grievance assistanc...
# 98   AI: Hi! I am your consumer grievance assistanc...
# 99   AI: Hi! I am your consumer grievance assistanc...
# 100  AI: Hi! I am your consumer grievance assistanc...
# 101  AI: Hi! I am your consumer grievance assistanc...
#
#                                                  Turns  \
# 0    {1: {'context': '\nDocument 0:\n5 of the Consu...
# 1    {1: {'context': "\nDocument 0:\nproducts, etc....
# 2    {1: {'context': "\nDocument 0:\nof the product...
# 3    {1: {'context': '\nDocument 0:\nboarding   to ...
# ...

# %%
data['inconsistency_count'] = data['Result'].str.count(r'\b\d+\.')
data['turn_count'] = data['Chat'].str.count(r'AI:') - 1
mean_values = data.groupby('Version').apply(lambda x: (x['inconsistency_count'].sum() / x['turn_count'].sum()))
display(mean_values)
mean_values = data.groupby('Version').apply(lambda x: (x['inconsistency_count'] / x['turn_count']).mean())
display(mean_values)
data
# Out:
# /tmp/ipykernel_87425/158922934.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   mean_values = data.groupby('Version').apply(lambda x: (x['inconsistency_count'].sum() / x['turn_count'].sum()))
# Version
# v0    0.988889
# v1    0.842105
# v2    0.460784
# v3    0.894737
# dtype: float64
# /tmp/ipykernel_87425/158922934.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# ...
