# %%
import pandas as pd
import ast

# %%
data = pd.read_csv('./results.csv')
data
# Out:
#      chat  turn                                            context  \
# 0       0     0  \nDocument 0:\n3. The next step is to reach th...
# 1       0     1  \nDocument 0:\ngrievance with the manufacturin...
# 2       0     2  \nDocument 0:\nwaiving   claims   has   not   ...
# 3       0     3  \nDocument 0:\nare   required. ○ One   copy   ...
# 4       0     4  \nDocument 0:\nare   required. ○ One   copy   ...
# ..    ...   ...                                                ...
# 635   114     1  \nDocument 0:\nduplicate shares 4. Delay/ Non-...
# 636   114     2  \nDocument 0:\ncylinder is less in weight or n...
# 637   114     3  \nDocument 0:\nWhile   the   passenger   can  ...
# 638   114     4  \nDocument 0:\nthe   remedy   sought. 2. Filin...
# 639   114     5  \nDocument 0:\nContact - Customers can initiat...
#
#                                                history  \
# 0    The user shares that they got a tattoo from XY...
# ...

# %%
example = data.iloc[0]
display(ast.literal_eval(example["hallucinated_texts"]))
example["response"][ast.literal_eval(example["hallucinated_starts"])[0]:ast.literal_eval(example["hallucinated_ends"])[0]]
# Out:
# [" I can provide you with a sample draft if you'd like.",
#  '1800-11-4000)',
#  ' such as photographs of the tattoo, medical reports, or communication',
#  '?']
# " I can provide you with a sample draft if you'd like."

# %%
data2 = pd.read_csv('./recombined_results.csv')
data2
# Out:
#      chat  turn                                            context  \
# 0       0     0  \nDocument 0:\n3. The next step is to reach th...
# 1       0     1  \nDocument 0:\ngrievance with the manufacturin...
# 2       0     2  \nDocument 0:\nwaiving   claims   has   not   ...
# 3       0     3  \nDocument 0:\nare   required. ○ One   copy   ...
# 4       0     4  \nDocument 0:\nare   required. ○ One   copy   ...
# ..    ...   ...                                                ...
# 635   114     1  \nDocument 0:\nduplicate shares 4. Delay/ Non-...
# 636   114     2  \nDocument 0:\ncylinder is less in weight or n...
# 637   114     3  \nDocument 0:\nWhile   the   passenger   can  ...
# 638   114     4  \nDocument 0:\nthe   remedy   sought. 2. Filin...
# 639   114     5  \nDocument 0:\nContact - Customers can initiat...
#
#                                                history  \
# 0    The user shares that they got a tattoo from XY...
# ...
