# %%
import pandas as pd
import ast

# %%
data1 = pd.read_csv('./expanded_dataset.csv')
data1
# Out:
#       chat  turn                                            context  \
# 0        0     0  \nDocument 0:\n3. The next step is to reach th...
# 1        0     0  \nDocument 0:\n3. The next step is to reach th...
# 2        0     0  \nDocument 0:\n3. The next step is to reach th...
# 3        0     0  \nDocument 0:\n3. The next step is to reach th...
# 4        0     0  \nDocument 0:\n3. The next step is to reach th...
# ...    ...   ...                                                ...
# 6190   114     5  \nDocument 0:\nContact - Customers can initiat...
# 6191   114     5  \nDocument 0:\nContact - Customers can initiat...
# 6192   114     5  \nDocument 0:\nContact - Customers can initiat...
# 6193   114     5  \nDocument 0:\nContact - Customers can initiat...
# 6194   114     5  \nDocument 0:\nContact - Customers can initiat...
#
#                                                 history  \
# 0     The user shares that they got a tattoo from XY...
# ...

# %%
data2 = pd.read_csv('./results.csv')
data2
# Out:
#       chat  turn                                            context  \
# 0        0     0  \nDocument 0:\n3. The next step is to reach th...
# 1        0     0  \nDocument 0:\n3. The next step is to reach th...
# 2        0     0  \nDocument 0:\n3. The next step is to reach th...
# 3        0     0  \nDocument 0:\n3. The next step is to reach th...
# 4        0     0  \nDocument 0:\n3. The next step is to reach th...
# ...    ...   ...                                                ...
# 6190   114     5  \nDocument 0:\nContact - Customers can initiat...
# 6191   114     5  \nDocument 0:\nContact - Customers can initiat...
# 6192   114     5  \nDocument 0:\nContact - Customers can initiat...
# 6193   114     5  \nDocument 0:\nContact - Customers can initiat...
# 6194   114     5  \nDocument 0:\nContact - Customers can initiat...
#
#                                                 history  \
# 0     The user shares that they got a tattoo from XY...
# ...

# %%
data3 = pd.read_csv('./recombined_results.csv')
display(data3[["response", "hallucination"]].iloc[0].to_dict())
data3
# Out:
# {'response': "Covering medical expenses is a reasonable expectation from a service provider like a tattoo parlour. Since the tattoo parlour has denied liability, you may need to take further action to seek compensation. As a first step, I would recommend drafting a formal complaint letter to the tattoo parlour, stating the details of the incident, the harm caused, and the relief you're seeking. I can provide you with a sample draft if you'd like. Additionally, you can also file a complaint with the National Consumer Helpline (1800-11-4000) for immediate assistance. They can guide you on the next steps to take and provide you with the contact details of the relevant consumer court or authority to file a complaint. Before we proceed, I have one more question: Do you have any evidence or documentation to support your claim, such as photographs of the tattoo, medical reports, or communication with the tattoo parlour?",
# ...

# %%
data4 = pd.read_csv('./recombined_results_with_blocks.csv')
display(eval(data4[["response", "hallucination"]].iloc[2].to_dict()['hallucination']))
data4
# Out:
# ['The SDRC is a quasi-judicial body that deals with consumer disputes at the state level. To find the contact details of the SDRC in Telangana, you can visit the National Consumer Helpline website (nch.nic.in) and search for the contact information of the SDRC in Telangana. You can also try searching online for "Telangana State Consumer Dispute Redressal Commission" or "Telangana Consumer Grievance Redressal Forum". Alternatively, you can also contact the District Consumer Dispute Redressal Forum (DCDRF) in the district where the tattoo parlour is located. The DCDRF is the first level of consumer dispute redressal at the district level.',
#  'You can find their contact details on the official website of the Government of Telangana.',
#  "However, as this is a state-level issue, it's best to start with the state-level authorities first. Would you like me to provide you with the contact details of the CCPA or the Consumer Affairs Department of Telangana?"]
# ...
